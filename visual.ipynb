# %%
import pandas as pd
import numpy as np

# %%
# Sample DataFrame
data = pd.DataFrame({
    'Year': [2010, 2011, 2012, 2013, 2014],
    'Sales': [100, 150, 200, 250, 300],
    'Profit': [20, 30, 50, 70, 90]
})

# Plotting both Sales and Profit over time
data.plot(x='Year', y=['Sales', 'Profit'], kind='line', title="Sales and Profit Over Time")
# Out:
# <Axes: title={'center': 'Sales and Profit Over Time'}, xlabel='Year'>

# %%
data = pd.DataFrame({
    'usage_of_dictionary': [0, 50, 100, 20, 30, 0],
    'you_need_to_figure_it_on_your_own': [100, 70, 40, 90, 80, 100],
    'materials': ['python language', 'data structures', 'chatgpt', 'mongodb', 'psql', 'gql'],
})
data.plot(
    x="materials",
    y=["usage_of_dictionary", "you_need_to_figure_it_on_your_own"], 
    title="tomer's plot",
    kind="line"
)
# Out:
# <Axes: title={'center': "tomer's plot"}, xlabel='materials'>

# %%
data = pd.DataFrame({
    'lecturers': ['enosh', 'tomer', 'matanel', 'itshak', 'shmuel'],
    'muscles': [100.0, 20.2, 47.90, 01.1, 68.0],
    'afraid_of_shmuel': [0.0, 22.2, 8.8, 89.90, 60.0],
})
data.plot(
    x="lecturers",
    y=["muscles", "afraid_of_shmuel"], 
    title="who's afraid of the shmuel",
    kind="line"
)
# Out:
# <Axes: title={'center': "who's afraid of the shmuel"}, xlabel='lecturers'>

# %%
data = pd.read_json('./students.json')
data
# Out:
#                        Name    Age  Uses_ChatGPT  Late_Submissions  \
# 0             David HaMagid   22.0           1.0               3.0
# 1            Ariel Ben HAim  178.0           1.0              13.0
# 2              Reuven Cohen   21.0           0.0               NaN
# 3           Menachem Albert   39.0           1.0               1.0
# 4               Moti Amrami   17.0           1.0               NaN
# 5              Yehuda Zeevi   23.0           1.0               4.0
# 6               Yair Achrak    NaN           1.0               0.0
# 7   Menachem Mendel Naftali   24.0           0.0               2.0
# 8           Benjamin Talker   19.0           1.0               5.0
# 9         Chaim Tzvi Shtern   22.0           NaN               1.0
# 10         Yeshayahu Reiner   21.0           1.0               2.0
# 11               Aaron Oren   23.0           1.0               0.0
# 12        Mordechai Wexberg   15.0           1.0               0.0
# ...
